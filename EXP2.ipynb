# %% [markdown]
# EXP 2 : STUDY OF LIST IN PYTHON (NAME - SAUMYA SHREE) (PRN: 25070123161)

# %%
list1=["apple","banana","orange"]
print(list1)
# Out:
# ['apple', 'banana', 'orange']

# %%
list2=[2,2,3,4,"paris",True]
print(list2)
# Out:
# [2, 2, 3, 4, 'paris', True]

# %%
list3=["apple","orange","cherry","apple"]
print(list3)
# Out:
# ['apple', 'orange', 'cherry', 'apple']

# %%
list4=["apple","orange","cherry","mango","kiwi"]
print(list4[2])
print(list4[-3])
print(list4[1:4])
print(list4[:4])
print(list4[2:])
# Out:
# cherry
# cherry
# ['orange', 'cherry', 'mango']
# ['apple', 'orange', 'cherry', 'mango']
# ['cherry', 'mango', 'kiwi']

# %%
list5=["apple","orange","mango"]
list5[2]="cherry"
print(list5)
list5[1]=2
print(list5)
# Out:
# ['apple', 'orange', 'cherry']
# ['apple', 2, 'cherry']

# %%
list6=["apple","orange","cherry"]
list6.append("mango")
print(list6)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list7=["apple","orange","cherry"]
list7.insert(1,"mango")
print(list7)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list8=["apple","banana","orange"]
list9=["kiwi","cherry"]
list8.extend(list9)
print(list8)
list9.extend(list8)
print(list9)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'cherry']
# ['kiwi', 'cherry', 'apple', 'banana', 'orange', 'kiwi', 'cherry']

# %%
marks=[80,82,66,76,83]
print(max(marks))
print(min(marks))
print(sum(marks))
print(sorted(marks))
average = sum(marks)/len(marks)
print(average)
# Out:
# 83
# 66
# 387
# [66, 76, 80, 82, 83]
# 77.4

# %%
Groceries = ["Rice","Wheat","Flour","Sugar","Bread"]
Groceries.append("Vegetables")
print(Groceries)
Groceries.remove("Sugar")
Groceries.remove("Bread")
print(Groceries)
print("Final shopping list =",Groceries)
# Out:
# ['Rice', 'Wheat', 'Flour', 'Sugar', 'Bread', 'Vegetables']
# ['Rice', 'Wheat', 'Flour', 'Vegetables']
# Final shopping list = ['Rice', 'Wheat', 'Flour', 'Vegetables']
